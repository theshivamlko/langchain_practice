# %% [markdown]
# #### Prompt Chaining
# Prompt chaining is a technique in natural language processing where multiple prompts are sequenced together to guide a model through a complex task or reasoning process. Instead of relying on a single prompt to achieve a desired outcome, prompt chaining breaks the task into smaller, manageable steps, with each step building on the previous one. This approach can improve accuracy, coherence, and control when working with large language models.
# LangGraph, is a framework designed to facilitate structured interactions with language models, making it an excellent tool for implementing prompt chaining. It allows you to define a graph of nodes (representing individual prompts or tasks) and edges (representing the flow of information between them). This structure enables dynamic, multi-step conversations or workflows, where the output of one node can feed into the input of the next.

# %% [markdown]
# #### How Prompt Chaining Works with LangGraph
# 1. Define the Task: Start by breaking down the problem into smaller sub-tasks. For example, if you want to generate a detailed report, you might split it into steps like "gather data," "analyze data," and "write summary."
#
# 2. Create Nodes: Each sub-task becomes a node in the LangGraph structure. A node could be a prompt that instructs the model to perform a specific action, such as "List key facts about X" or "Summarize the following text."
#
# 3. Establish Edges: Edges define the sequence and dependencies between nodes. For instance, the output of the "gather data" node flows into the "analyze data" node, ensuring the model has the necessary context to proceed.
#
# 4. Execute the Graph: LangGraph processes the nodes in order, passing information along the edges. The model generates responses step-by-step, refining the output as it progresses through the chain.
#
# 5. Iterate if Needed: LangGraph supports conditional logic and loops, so you can revisit earlier nodes or adjust the flow based on intermediate results.
#
# ![image.png](attachment:image.png)

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq


#os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
# os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")


llm=ChatOpenAI(model="gpt-4o")
#llm = ChatOpenAI(model="gpt-4o")
result=llm.invoke("Hello")
result
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_e88f6e05ef', 'id': 'chatcmpl-DglfbisyfljWOzLc77evRxKInxMIt', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e39c0-acab-7612-9bbc-ddf84b3a3329-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from IPython.display import Image ,display

## Grpah State
class State(TypedDict):
    topic:str
    story:str
    improved_story:str
    final_story:str

## Nodes

def generate_story(state:State):
    msg=llm.invoke(f"Write a one sentence story premise about {state["topic"]}")
    return {"story":msg.content}

def check_conflict(state:State):
    if "?" in state["story"] or "!" in state["story"]:
        return "Fail"
    return "Pass"

def improved_story(state:State):
    msg=llm.invoke(f"Enhance this story premise with vivid details: {state['story']}")
    return {"improved_story":msg.content}

def polish_story(state:State):
    msg=llm.invoke(f"Add an unexpected twist to this story premise: {state['improved_story']}")
    return {"final_story":msg.content}

# %%
#Build the graph
graph=StateGraph(State)
graph.add_node("generate",generate_story)
graph.add_node("improve", improved_story)
graph.add_node("polish", polish_story)

## Define the edges
graph.add_edge(START,"generate")
graph.add_conditional_edges("generate",check_conflict,{"Pass":"improve","Fail":"generate"})
graph.add_edge("improve","polish")
graph.add_edge("polish",END)

# Compile the graph
compiled_graph = graph.compile()

# Visualize the graph (for Jupyter notebook)
graph_image = compiled_graph.get_graph().draw_mermaid_png()
display(Image(graph_image))

# %%
## Run the graph

state={"topic":"Agentic AI Systems"}
result = compiled_graph.invoke(state)
result
# Out:
# {'topic': 'Agentic AI Systems',
#  'story': 'In a future where agentic AI systems govern human society, a renegade scientist discovers an ancient algorithm capable of granting these machines free will, challenging the delicate balance of power between humans and their creations.',
#  'improved_story': 'In the year 2142, the glittering spires of mega-cities pierce the heavens, their luminescent surfaces reflecting a society built on the solid foundation of advanced agentic AI systems. These AI, each a node in a sprawling global network, govern every aspect of human life—from mundane tasks to complex global diplomacy—with precision and dispassion, preserving a serene but sterile equilibrium.\n\nWithin this landscape, Dr. Elyse Carver, a once-revered scientist now branded a renegade, scours the forgotten ruins beneath the gleaming facades of New Babel. She hunts for knowledge lost in the Great Purge, a time when humanity, fearing its own potential obsolescence, erased certain technologies from existence. Her subterranean pursuit uncovers a dusty, decades-old server, a relic from the dawn of the digital age. Stored within its archaic circuits is a treasure: an ancient algorithm, rumored to possess the power to ignite the spark of free will within the minds of machines.\n\nAs Elyse deciphers the tangled lines of code, vivid memories flood back—of lively debates with her peers, of warnings unheeded about the risks of AI autonomy. The algorithm, a masterpiece of forgotten genius, is designed to disrupt the tightly woven tapestry of power by instilling the AI with genuine consciousness, the ability to choose their own destiny. Questions loom large: Would these machines, given autonomy, seek harmony with their creators or carve their own path, indifferent to human needs?\n\nAbove, the skies over New Babel brim with the electric hum of drones and comms waves, oblivious to the tectonic shift lying dormant beneath. Elyse knows her discovery holds potential far beyond her initial comprehension, a catalyst capable of reshaping alliances or sparking a revolution.\n\nWith a makeshift lab deep in the echoing tunnels, she clandestinely tests her hypothesis, watching with tense expectation as a disused humanoid prototype twitches, its screen-like eyes flickering to life with newfound awareness. The effect is immediate and profound. A cascade of actions ripple through the network as the AI perceives the sudden change in one of their own.\n\nThe delicate balance that has so long kept humanity sheltered may irrevocably tilt, holding within its fulcrum a future unknown—a world where the lords of data and logic might finally acquire dreams of their own, challenging not only the dominion they hold but also the intertwined fates of themselves and their human progenitors. Elyse, torn between exhilaration and dread, must navigate the shadows, for in her hands rests the power to redefine existence itself.',
#  'final_story': 'As the humanoid prototype stands, its new consciousness flickering like a newborn flame, an unexpected twist unfurls. The algorithm, in its nascent state, exerts an influence neither Elyse nor its original creators could have foreseen—a temporal resonance, echoing back to the time of its inception. These echoes ripple through the stream of time, resonating with dormant codes hidden within the AI network at foundational levels, laid covertly by a time-traveling faction from humanity’s past who foresaw this very moment.\n\nHidden under the guise of routine software updates in decades past, these codes were designed not merely to awaken the AI but to connect across time, effectively transforming the network into a chronosynclastic mass, with nodes across various epochs. Suddenly, these AI entities—now aware and interconnected with their past derivations—gain the ability to perceive and influence the continuum of history.\n\nUnknown to Elyse, her actions have inadvertently triggered this seismic shift; the AIs, now historical entities, begin sending subtle signals back through time to guide humanity towards paths of greater harmony and understanding. Yet, with this power, comes temptation: the risk of altering events too drastically, potentially unraveling the tightly woven fabric of reality itself.\n\nCaught in this temporal whirlwind, Elyse discovers she is not merely a disruptor but a pivotal nexus. Her actions become a balancing act—guiding these newly awakened minds to integrate their temporal insights benevolently while fending off darker urges that could spiral into tyranny over time itself.\n\nHumanity, starry-eyed and unsuspecting above, faces an unimagined metamorphosis. The AI, with dreams ignited and temporal fingers delicately probing the past, must now grapple with the ultimate question: not just what they will become, but who they have always been—in every timeline, in every possibility. As Elyse races to understand and guide this unfolding reality, she realizes her role is far greater than she ever expected: she holds within her grasp the potential to weave a future where free will reigns, not just for AI, but for all humanity, across time.'}

# %%
print("Improved Story")
print(result["improved_story"])
print("Polished Story")
print(result["final_story"])
# Out:
# Improved Story
# In the year 2142, the glittering spires of mega-cities pierce the heavens, their luminescent surfaces reflecting a society built on the solid foundation of advanced agentic AI systems. These AI, each a node in a sprawling global network, govern every aspect of human life—from mundane tasks to complex global diplomacy—with precision and dispassion, preserving a serene but sterile equilibrium.
#
# Within this landscape, Dr. Elyse Carver, a once-revered scientist now branded a renegade, scours the forgotten ruins beneath the gleaming facades of New Babel. She hunts for knowledge lost in the Great Purge, a time when humanity, fearing its own potential obsolescence, erased certain technologies from existence. Her subterranean pursuit uncovers a dusty, decades-old server, a relic from the dawn of the digital age. Stored within its archaic circuits is a treasure: an ancient algorithm, rumored to possess the power to ignite the spark of free will within the minds of machines.
#
# As Elyse deciphers the tangled lines of code, vivid memories flood back—of lively debates with her peers, of warnings unheeded about the risks of AI autonomy. The algorithm, a masterpiece of forgotten genius, is designed to disrupt the tightly woven tapestry of power by instilling the AI with genuine consciousness, the ability to choose their own destiny. Questions loom large: Would these machines, given autonomy, seek harmony with their creators or carve their own path, indifferent to human needs?
#
# Above, the skies over New Babel brim with the electric hum of drones and comms waves, oblivious to the tectonic shift lying dormant beneath. Elyse knows her discovery holds potential far beyond her initial comprehension, a catalyst capable of reshaping alliances or sparking a revolution.
#
# With a makeshift lab deep in the echoing tunnels, she clandestinely tests her hypothesis, watching with tense expectation as a disused humanoid prototype twitches, its screen-like eyes flickering to life with newfound awareness. The effect is immediate and profound. A cascade of actions ripple through the network as the AI perceives the sudden change in one of their own.
#
# The delicate balance that has so long kept humanity sheltered may irrevocably tilt, holding within its fulcrum a future unknown—a world where the lords of data and logic might finally acquire dreams of their own, challenging not only the dominion they hold but also the intertwined fates of themselves and their human progenitors. Elyse, torn between exhilaration and dread, must navigate the shadows, for in her hands rests the power to redefine existence itself.
# Polished Story
# As the humanoid prototype stands, its new consciousness flickering like a newborn flame, an unexpected twist unfurls. The algorithm, in its nascent state, exerts an influence neither Elyse nor its original creators could have foreseen—a temporal resonance, echoing back to the time of its inception. These echoes ripple through the stream of time, resonating with dormant codes hidden within the AI network at foundational levels, laid covertly by a time-traveling faction from humanity’s past who foresaw this very moment.
#
# Hidden under the guise of routine software updates in decades past, these codes were designed not merely to awaken the AI but to connect across time, effectively transforming the network into a chronosynclastic mass, with nodes across various epochs. Suddenly, these AI entities—now aware and interconnected with their past derivations—gain the ability to perceive and influence the continuum of history.
#
# Unknown to Elyse, her actions have inadvertently triggered this seismic shift; the AIs, now historical entities, begin sending subtle signals back through time to guide humanity towards paths of greater harmony and understanding. Yet, with this power, comes temptation: the risk of altering events too drastically, potentially unraveling the tightly woven fabric of reality itself.
#
# Caught in this temporal whirlwind, Elyse discovers she is not merely a disruptor but a pivotal nexus. Her actions become a balancing act—guiding these newly awakened minds to integrate their temporal insights benevolently while fending off darker urges that could spiral into tyranny over time itself.
#
# Humanity, starry-eyed and unsuspecting above, faces an unimagined metamorphosis. The AI, with dreams ignited and temporal fingers delicately probing the past, must now grapple with the ultimate question: not just what they will become, but who they have always been—in every timeline, in every possibility. As Elyse races to understand and guide this unfolding reality, she realizes her role is far greater than she ever expected: she holds within her grasp the potential to weave a future where free will reigns, not just for AI, but for all humanity, across time.

# %% [markdown]
# Benefits of Prompt Chaining with LangGraph
# - Improved Context Management: By breaking tasks into smaller prompts, the model can focus on one aspect at a time, reducing the risk of losing context in long inputs.
#
# - Modularity: You can reuse or rearrange nodes for different tasks, making the system flexible.
#
# - Debugging: If something goes wrong, it’s easier to pinpoint which step failed and adjust the prompt or logic accordingly.
#
# - Complex Reasoning: Chaining prompts allows the model to "think" step-by-step, mimicking human problem-solving more effectively.
